# %% [markdown]
# # Libraries
#
# ## 1 Tensorflow
# - Tensorflow is a deep learning framework
# - This library was created by google in the year of 2015 and it is open source
# - Tensorflow is the most famous deep learning library
# - It is entirely based on python programming language and use for numerical computation and data flow , which makes machine learning faster and easier
# - Tensorflow is based on graph computation

# %%
# Tensorflow installation

# !pip install tensorflow
# Out:
# zsh:1: command not found: pip

# %%
# !python -m pip install tensorflow
# Out:
# zsh:1: command not found: python

# %%
pip install tensorflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.7/200.7 MB 3.0 MB/s eta 0:00:0000:0100:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 3.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.9/676.9 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 3.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 4.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 2.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [tensorflow]6 [tensorflow]]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print(tf.__version__)

# %%
import sys
sys.version

# %% [markdown]
# ## Update
# - Tensorflow 2nd version onwards keras library was in built
# - So we no need to install keras separately

# %%
conda create -n tf_env python=3.10
# Out:
# Jupyter detected...
#
# CondaToSNonInteractiveError: Terms of Service have not been accepted for the following channels. Please accept or remove them before proceeding:
#     • https://repo.anaconda.com/pkgs/r
#
# To accept a channel's Terms of Service, run the following and replace `CHANNEL` with the channel name/URL:
#     ‣ conda tos accept --override-channels --channel CHANNEL
#
# To remove channels with rejected Terms of Service, run the following and replace `CHANNEL` with the channel name/URL:
#     ‣ conda config --remove channels CHANNEL
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda activate tf_env
# Out:
# CondaError: Run 'conda init' before 'conda activate'
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print(tf.__version__)

# %%
import sys
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 11:23:37) [Clang 14.0.6 ]'

# %%
import sys
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 11:23:37) [Clang 14.0.6 ]'

# %% [markdown]
# ## 2 Pytorch
# - Pytorch is a deep learning framework
# - Pytorch is a deep learning library created by facebook in the year of 2016 and it is an open source
#
# # Note
# - CNTK is another deep learning framework created by microsoft but not that much popular compare to tensorflow and pytorch
#
#
# ## 3 Keras
# - Keras is an open - source high level Neural Network library which was written in python is capable enough to run on Theano , Tensorflow, or CNTK
# - It was developed by one of the Google engineers , Francois Chollet
# - It is user-friendly , extensible and faster experimentation with deep neural networks
# - It supports Convolution Networks and REcurrent Networks Individually also their combination
#
#
# # Machine Learning Steps
# ### 1. Importing libraries
# ### 2. Loading the datasets
# ### 3. Data preparation
# ### 4. Splitting the dataset
# ### 5. Creating the model (Algorithm)     (Creating a model Linera Regression )
# ### 6. Model training
# ### 7. Prediction
#
#
#
# # Deep Learning Steps
# ### 1. Importing libraries
# ### 2. Loading the datasets
# ### 3. Data preparation
# ### 4. Splitting the dataset
#
# ## 5. Creating the model   (Creating a neural networks)  model = sequential()  class keras
# ## 6. Model Compilation   model.compile()
# ### 7. Model training      model.fit()
# ### 8. Prediction        model.predict()
#
#
# ## 4 Steps to create deep learning models with Keras
#
# ### 4.1 Define your model
# - Create a Sequential model and add configured layers.
# ### 4.2 Compile your model
# - Specify loss function and optimizers and cell the compile() method on the model
# ### 4.3 Fit your model
# - Train the model on a sample of data by calling the fit() method on the model.
# ### 4.4 Make predictions
# - Use the model to generate prediction on new data by calling the methods such as evaluate() or predict() on the model
