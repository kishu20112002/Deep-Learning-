# %% [markdown]
# # Deep Learning Steps
# ### 1. Importing libraries
# ### 2. Loading the datasets
# ### 3. Data preparation
# ### 4. Splitting the dataset
# ### 5. Creating the model (Algorithm)
# ### 6. Model Compilation
# ### 7. Model training
# ### 8. Prediction
#
#
#
# ## NN flow
# # 1. Input neurons
# # 2. Weight
# # 3. Summation function
# # 4. bias
# # 5. Activation Function
# # 6. cost function
# # 7. Optimization
# # 8. Output
#
# ## Math formula
# - input x weights + bias => Output

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from numpy import loadtxt    # in this we can load file but not column its in array
from sklearn.model_selection import StratifiedKFold

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()     # object created  # emtpy network

obj1=Dense(16,           # layer created 
           input_shape=(8,))      # 16 hidden layer  and 8 is input layer

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input


model = Sequential()

layers=Dense(
    p1=hidden_layers
    p2=input_layers
    p3=weights intialization
    p4=activation intialization 
        
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()

hidden_input=Dense(16,
                   input_shape=(8,)
                   ,kernel_initializer="random_uniform",
                   activation="relu")
model.add(hidden_input)

model.compile(optimizer=..,loss=..,metrics=...)

model.fit(X,
          y,
          epochs=...,
          batch_size=..)
