# %% [markdown]
# ## 1 Deep Learning - Introduction
#
# #### Python => How to create program
# #### Pandas => - How to Analyse the data
#              - How to create Dataframe
# #### ML  => How to create a model
#          - Prediction using model
# ## DL => How to create a model
#         - Prediction using model
#
# ## types of Data => Structure
#                    - Unstucture
#                    - Semi Structure
#
# ### ML   => very well Strutured Data but bit difficult to Unstructured
#
# ### DL => Structure, Unstructure , semi
#
#
# ## Unstrcture
# - Text format , image , audio , video......
#
# ## By using ML/DL/NLP => We are creating a model
#                         - To do prediciton
#                         - object detection
#
#
#
#
# ## 1.1 Machine learning
# - Machine learning is a part of artifical intelligence
# - Machine learning is a technique to learn from the data and apply the prediction on new data
#
# ### Example
# - Amazon using machine learning to give better product choice recommendations their costumers based on their preferences
# - Netflix uses machine learning to give better suggestions to their users of the TV series or movie or shows that they would like to watch & many more
#
# ## 1.2 Deep learning
# - Deep learning is subset of machine learning
# - The main difference between deep and machine learning is machine learning models works better but the model still needs some guidance
# - If a machine learning model returs an inaccurate prediction then the programmer needs to fix that problem explicity
# - In the case of the deep learning the model does it by itself
#
# ### Example
# - Automatic car driving system is a good example of deep learning
#
#
#
# ### 1.3 Artifical intelligence
# - AI means the ability of computer program to function like a human brain
# - Machine learning and deep learning are the subsets of AI
# - The MOTO of AI is to replicate a human brain the way a human brain thinks, works and functions.
# - Currently AI is not yet fully implemented but we are very near to establish that too.
#
# ### Example
# - Sophia the most advanced AI model present today
#
#
# ## 2 Different models
# - In ML we have worked with different models like linear regression logistic regression, KNN , Decision Tree & etc
#
# ## Deep learning
# 1. ANN == FFNN
# 2. CNN  (image , Computer vision)
# 3. RNN  (text data analytis)
#
# ## 3 Lets uderstand Deep learning
# - Deep learning is a subset of machine learning using in Artifical Nerual Networks, Which are insipred by the human brain
# - Deep learning is able to capture required features automatically and solving the problem
# - DL is the technique that comes closest to the way human learn
# ## - Deep learning method use nerural network architeture
# - That is why deep learning is often referred to as "deep nerural networks"
#
#
# - Python => FP + OOP
# - Pandas => DataFrame
# - ML => Algorithms
# - DL => Neural Network
#
#
# ## 4 Differences between Deep learning and Machine learning
#
# ### 4.1 Data
# - Data learning models works with very huge data
# - The more data you give to neural network it will show much greater accuracy than other machine learning models
#
# ### 4.2 Computation Hardware CPU ,GPU
# - ML models works with CPU [Central Processing Units]
# - DL models works with GPU [ Graphical Processing Units and ]TPU [ Tensor Processing Units]
#   - These are highly advanced processing systems
#
# ### 4.3 CPU
# - It is Central Processing Unit
# - It is a brain to the computer
# - Processing serial instruction
# - Good at speed during processing
# - Consumes more memory during processing
# - Companies like Intel , ARM , AMD produce the CPU and companies
#
# ### 4.4 GPU
# - It is Graphical Processing Unit
# - Processing parallel instrution
# - Having very good speed compare to CPU
# - Consumes very less memory
# - Companies like Nvidia, AWD's ATI produce the GPU
#
# ## 5 Feature selection
# - In deep learning neural networks take care of the feature selection automatically
# - It decides a paricular feature is important or not and reduces thr corresponding weights to almost zero
# - In machine learning algorithm , feature selection plays an important role and we need to do keep focus on this
#
# ## 6 Performance
# - Deep learning given very good performance compare to machine learning
# - DL => With more data neural network accuaracy increases
#    - With less data Neural Network has less accuaracy
#
# - ML => With more data accuaracy of traditional ML model plateaus
#
# ## 7 Neural networks
# - Deep learning is implementeed with the help of neural networks
# - A nerual network is a network or circuit of neurons to slove the problem
# - The idea behind Nerural Network is the biological neurons , Which is nothing but a brain cell
# - Neural networks may have multiple hidden layers
#
# #### Machine Learning
# - Linear Regression
# - Logistic Regression
# - Random Forest
#
# #### Deep learning  => No predefined algs
#                         - We need to create algorithm
#                         - By using neural network
#
# ## 8 types of neural networks
# - There are mainly 3 types of neural networks in deep learning
#  - Artifical Neural Networks (ANN) or Feed-Forword Neural network
#  - Convolution Neural Networks (CNN)  => image
#  - Recurrent Neural Networks (RNN)   => text
#
# ## 8.1 Deep learning application
# - Self Driving Cars
# - Frand News Detection
# - Natural Lanuage Processing
# - virtual Assistants
# - Entertainment
# - Visual Recognition
# - Fraud Detection
# - Healthcare
# - Language Translation & etc
