# %% [markdown]
# ## 1 Create model (Neural Network Model) By using Keras
# - Sequential is a predefined class in keras package
# - By using this we can create a model

# %%
from tensorflow.keras.models import Sequential
model=Sequential()

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.16.2

# %%
from tensorflow.keras.models import Sequential
model=Sequential()

# %% [markdown]
# ## 1.1 Model layers
# - Once model created then we need to add layers to model
#   - Creating layers means , create object to Dense class
# - We need to specify number of features to input layer
#   - Below example, 8 means its features

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()     # object created  # emtpy network

obj1=Dense(16,           # layer created 
           input_shape=(8,))      # 16 hidden layer  and 8 is input layer
# Out:
# /opt/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # 1 Create object to sequantial class     => emtpy network
# # 2 Create object to Dense  => layers created
# # 3 add layers to network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()

hidden_input=Dense(16,input_shape=(8,))

model.add(hidden_input)
# Out:
# /opt/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-01-08 11:49:54.899820: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2026-01-08 11:49:54.901039: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2026-01-08 11:49:54.903195: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2026-01-08 11:49:54.903530: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

model = Sequential()

# Input layer
model.add(Input(shape=(8,)))

# Hidden layer
model.add(Dense(16, activation='relu'))

# Output layer (example)
model.add(Dense(1))

# %%
# two layers

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

model=Sequential()

first_hidden_input=Dense(16,input_shape=(8,))
secound_hidden_input=Dense(16,input_shape=(8,))

model.add(first_hidden_input)
model.secound_hidden_input(secound_hidden_input)
# Out:
# /opt/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## 1.2 Important properties to layers
# - Main properties
#  # - Weight initialization
#  # - Activation functions
#
# ### 1.2.1 Weight Initialization
# - By using kernel_initializer
#   - random_uniform, random_normal, zero

# %%
# Weight Initialization 

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

model=Sequential()

hidden_input=Dense(16,
                   input_shape=(8,)
                   ,kernel_initializer="random_uniform")    # Weight Initialization 


model.add(hidden_input)
# Out:
# /opt/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### 1.2.2 Activation Function
# - We need to use activation functions like
#   1. Softmax
#   2. rectified linear (ReLU),
#   3. tanh,
#   4. sigmoid

# %%
# Activation Function 

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

model=Sequential()

hidden_input=Dense(16,
                   input_shape=(8,),
                   kernel_initializer="random_uniform",
                   activation="relu")
# Out:
# /opt/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


model = Sequential()

layers=Dense(
    p1=hidden_layers
    p2=input_layers
    p3=weights intialization
    p4=activation intialization 
        
)

model.add(layers)
# Out:
#   Cell In[17], line 8
#     p1=hidden_layers
#        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ## 2 Model Compilation
# - Once model created then we need to compile the model (Neural Network Model).
# - During this step TensorFlow converts the model into a graph so the training cab be carried out efficiently
# - We can compile by calling compile() method
# - Important attributes in compile() method
#   - Model optimizer
#   - Loss function
#   - Metrics

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()

hidden_input=Dense(16,
                   input_shape=(8,)
                   ,kernel_initializer="random_unforim",
                   activation="relu")
model.add(hidden_input)

model.compile(optimizer=..,loss=..,metrics=...)
# Out:
#   Cell In[19], line 12
#     model.compile(optimizer=..,loss=..,metrics=...)
#                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 3 Model Training
# - Once model created and compiled then next step is to train the model
# - We can train the model by using fit(..) method

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()

hidden_input=Dense(16,
                   input_shape=(8,)
                   ,kernel_initializer="random_unforim",
                   activation="relu")
model.add(hidden_input)

model.compile(optimizer=..,loss=..,metrics=...)

model.fit(X,
          y,
          epochs=...,
          batch_size=..)
model.predict(X)
