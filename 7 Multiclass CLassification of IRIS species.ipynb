# %% [markdown]
# # => Multiclass CLassification of IRIS species
#
# ## 1 Multi class classification
# - We can solve iris multi class classification problem by using deep learning
#
# ## 2 Steps to solve the problem
# - Problem Description
# - Import required libraries
# - Load the Dataset
# - Encode the output Variable
# - Evalute the Model with K - Fold Cross - Validation
# - Complete Example
#
# ## 3 IRIS problem description
# - This dataset is well studied and makes a good problem for practicing on nerural network because all four input variables are numeric and have the same scale in centimetres.
# - The attributes for this dataset can be summarized as follows
#   - 1. Sepal length in centimetres
#     2. Sepal width in centimetres
#     3. Petal length in centimetres
#     4. Petal width in centimetres
#     5. Class (the flower species)
#
# - This is a multiple classification problem
# - there are 3 types of flowers
# - Total 150 instances
#
# ## 4 Problem description
# - This dataset is well studied and makes a good problem for practicing on neural networks because all four input variables are numeric and have the same scale in centimetres

# %%
# Loading the dataset 

import pandas as pd 

df=pd.read_csv("/Users/apple/Downloads/Iris (1).csv",skiprows=1,header=None)

print("Loaded the dataset")

print(df)
# Out:
# Loaded the dataset
#        0    1    2    3    4               5
# 0      1  5.1  3.5  1.4  0.2     Iris-setosa
# 1      2  4.9  3.0  1.4  0.2     Iris-setosa
# 2      3  4.7  3.2  1.3  0.2     Iris-setosa
# 3      4  4.6  3.1  1.5  0.2     Iris-setosa
# 4      5  5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...  ...             ...
# 145  146  6.7  3.0  5.2  2.3  Iris-virginica
# 146  147  6.3  2.5  5.0  1.9  Iris-virginica
# 147  148  6.5  3.0  5.2  2.0  Iris-virginica
# 148  149  6.2  3.4  5.4  2.3  Iris-virginica
# 149  150  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
## splitting the dataset

import pandas as pd 

df=pd.read_csv("/Users/apple/Downloads/Iris (1).csv",skiprows=1,header=None)

X=df.iloc[:,0:4].astype(float).values
y=df.iloc[:,4].values

print(X)
print(y)
# Out:
# [[  1.    5.1   3.5   1.4]
#  [  2.    4.9   3.    1.4]
#  [  3.    4.7   3.2   1.3]
#  [  4.    4.6   3.1   1.5]
#  [  5.    5.    3.6   1.4]
#  [  6.    5.4   3.9   1.7]
#  [  7.    4.6   3.4   1.4]
#  [  8.    5.    3.4   1.5]
#  [  9.    4.4   2.9   1.4]
#  [ 10.    4.9   3.1   1.5]
#  [ 11.    5.4   3.7   1.5]
#  [ 12.    4.8   3.4   1.6]
#  [ 13.    4.8   3.    1.4]
#  [ 14.    4.3   3.    1.1]
#  [ 15.    5.8   4.    1.2]
#  [ 16.    5.7   4.4   1.5]
#  [ 17.    5.4   3.9   1.3]
#  [ 18.    5.1   3.5   1.4]
#  [ 19.    5.7   3.8   1.7]
#  [ 20.    5.1   3.8   1.5]
#  [ 21.    5.4   3.4   1.7]
#  [ 22.    5.1   3.7   1.5]
#  [ 23.    4.6   3.6   1. ]
#  [ 24.    5.1   3.3   1.7]
#  [ 25.    4.8   3.4   1.9]
#  [ 26.    5.    3.    1.6]
#  [ 27.    5.    3.4   1.6]
#  [ 28.    5.2   3.5   1.5]
#  [ 29.    5.2   3.4   1.4]
#  [ 30.    4.7   3.2   1.6]
#  [ 31.    4.8   3.1   1.6]
#  [ 32.    5.4   3.4   1.5]
#  [ 33.    5.2   4.1   1.5]
#  [ 34.    5.5   4.2   1.4]
# ...

# %%
# Encode the class values

import pandas as pd 
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder 


# load dataset 

df=pd.read_csv("/Users/apple/Downloads/Iris (1).csv",skiprows=1,header=None)


# Data prepartion

X=df.iloc[:,0:4].astype(float).values
y=df.iloc[:,4].values


encoder=LabelEncoder()
encoder.fit(y)
encoder_Y=encoder.taranform(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 21
#      19 encoder=LabelEncoder()
#      20 encoder.fit(y)
# ---> 21 encoder_Y=encoder.taranform(y)
#
# AttributeError: 'LabelEncoder' object has no attribute 'taranform'
